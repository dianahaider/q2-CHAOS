# %% [markdown]
# # Boxplot for frequency per sample
# Yep

# %%
files = ['~/data/csv files/s2.csv','~/data/csv files/s11.csv']

# %%
import pandas as pd

# %%
s2 = pd.read_csv('~/data/csv files/s2.csv')
s11 = pd.read_csv('~/data/csv files/s11.csv')

# %%
df_merge_col = pd.merge(s2, s11, on='sample')
df_merge_col
# Out:
#              sample     f2    f11
# 0    16SV6-BB16.19D  11150  21854
# 1    16SV6-BB16.38A  10552  24174
# 2    16SV6-BB16.27D  10313  20980
# 3    16SV6-BB16.28D  10109  19845
# 4    16SV6-BB16.04A   9956  22350
# 5    16SV6-BB16.44A   9818  22091
# 6    16SV6-BB16.21C   9782  22453
# 7     16SV6-BB16.7D   9567  20196
# 8     16SV6-BB16.9D   9505  22527
# 9    16SV6-BB16.22D   9348  20022
# 10   16SV6-BB16.26D   9305  20046
# 11   16SV6-BB16.18D   9214  17706
# 12   16SV6-BB16.17D   9171  17565
# 13   16SV6-BB16.18B   9151  23975
# 14   16SV6-BB16.10D   9126  20137
# 15   16SV6-BB16.42A   9122  21549
# 16    16SV6-BB16.4C   9100  24615
# 17   16SV6-BB16.22C   9066  25031
# 18   16SV6-BB16.24D   8954  18467
# 19   16SV6-BB16.49A   8946  17243
# 20   16SV6-BB16.25D   8905  18486
# 21   16SV6-BB16.21D   8866  20338
# 22   16SV6-BB16.16D   8851  16964
# 23   16SV6-BB16.47A   8825  20423
# 24   16SV6-BB16.20D   8824  16206
# 25    16SV6-BB16.8D   8812  18081
# ...

# %%
def load_df(filenames):
    smpl = []
    for filename in filenames:
        smpl.append( (pd.read_csv(filename), filename) )
    return smpl

# %%
def merg(lst=list):
    merge = pd.merge(lst[1],lst[2], on='sample')
    if len(lst) > 2:
        for i in 1:len(lst):
                merge = pd.merge(merge, lst[i+2], on = 'sample')

# %% [raw]
# merge = pd.merge(s2,s11, on='sample')
